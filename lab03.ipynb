# %%
###################################################
# MC102 - Algoritmos e Programação de Computadores
# Laboratório 3 - Ingresso do Cinema
# Nome: Samuel Augusto de Souza
# RA: 261025
###################################################

# leitura de dados

diaSemana = int(input(''))
horaSessao = int(input(''))
minutoSessao = int(input(''))
estudante = input('')
pagamento = input('')
minutos = horaSessao*60 + minutoSessao

# valor do ingresso inteiro
# valor a pagar

def ticket(diaSemana, horaSessao, minutoSessao, estudante, pagamento):

  if estudante == 'N':

    if pagamento == 'C' and minutos >= 1110:
      
      if diaSemana == 1:
        ingresso = 30*0.7

      elif diaSemana == 2:
        ingresso = 20*0.5

      elif diaSemana == 3:
        ingresso = 20*0.5

      elif diaSemana == 4:
        ingresso = 30*0.5

      elif diaSemana == 5:
        ingresso = 30*0.5

      elif diaSemana == 6:
        ingresso = 40*0.7

      elif diaSemana == 7:
        ingresso = 40*0.8
  
    if pagamento == 'C' and minutos < 1110:
      
      if diaSemana == 1:
        ingresso = 30*0.7

      elif diaSemana == 2:
        ingresso = 15*0.5

      elif diaSemana == 3:
        ingresso = 15*0.5

      elif diaSemana == 4:
        ingresso = 15*0.5

      elif diaSemana == 5:
        ingresso = 20*0.5

      elif diaSemana == 6:
        ingresso = 20*0.5

      elif diaSemana == 7:
        ingresso = 30*0.8
        
    if pagamento == 'D' and minutos >= 1110:
      
      if diaSemana == 1:
        ingresso = 30

      elif diaSemana == 2:
        ingresso = 20

      elif diaSemana == 3:
        ingresso = 20

      elif diaSemana == 4:
        ingresso = 30

      elif diaSemana == 5:
        ingresso = 30

      elif diaSemana == 6:
        ingresso = 40

      elif diaSemana == 7:
        ingresso = 40
  
    if pagamento == 'D' and minutos < 1110:
      
      if diaSemana == 1:
        ingresso = 30

      elif diaSemana == 2:
        ingresso = 15

      elif diaSemana == 3:
        ingresso = 15

      elif diaSemana == 4:
        ingresso = 15

      elif diaSemana == 5:
        ingresso = 20

      elif diaSemana == 6:
        ingresso = 20

      elif diaSemana == 7:
        ingresso = 30

  if estudante == 'S' and pagamento == 'C' or estudante == 'S' and pagamento == 'D':

    if minutos >= 1110:

      if diaSemana == 1:
        ingresso = 30*0.5

      elif diaSemana == 2:
        ingresso = 20*0.5

      elif diaSemana == 3:
        ingresso = 20*0.5

      elif diaSemana == 4:
        ingresso = 30*0.5

      elif diaSemana == 5:
        ingresso = 30*0.5

      elif diaSemana == 6:
        ingresso = 40*0.5

      elif diaSemana == 7:
        ingresso = 40*0.5

    if minutos < 1110:
    
      if diaSemana == 1:
        ingresso = 30*0.5

      elif diaSemana == 2:
        ingresso = 15*0.5

      elif diaSemana == 3:
        ingresso = 15*0.5

      elif diaSemana == 4:
        ingresso = 15*0.5

      elif diaSemana == 5:
        ingresso = 20*0.5

      elif diaSemana == 6:
        ingresso = 20*0.5

      elif diaSemana == 7:
        ingresso = 30*0.5

  # saída do valor do ingresso

  print('Valor do ingresso: R$', format(ingresso, '.2f').replace('.', ','))

ticket(diaSemana, horaSessao, minutoSessao, estudante, pagamento)
# Out:
# Valor do ingresso: R$ 15,00
